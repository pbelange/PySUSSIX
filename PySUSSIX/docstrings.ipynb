# %%
import PySUSSIX.pysussix as sussix
for method in sussix.__dir__()[8:-1]:
    print(40*'=')
    print(method)
    print(40*'-')
    print(getattr(sussix,method).__doc__)
    print(40*'=' + '\n\n')
# Out:
# ========================================
# sussixnoo
# ----------------------------------------
# tunex,tuney,tunez,amplitude,phase,ox,ax,oy,ay,os,as = sussixnoo(x,xp,y,yp,s,sp,n_points)
#
# Wrapper for ``sussixnoo``.
#
# Parameters
# ----------
# x : input rank-1 array('d') with bounds (n_points)
# xp : input rank-1 array('d') with bounds (n_points)
# y : input rank-1 array('d') with bounds (n_points)
# yp : input rank-1 array('d') with bounds (n_points)
# s : input rank-1 array('d') with bounds (n_points)
# sp : input rank-1 array('d') with bounds (n_points)
# n_points : input int
#
# Returns
# -------
# tunex : float
# tuney : float
# tunez : float
# amplitude : rank-1 array('d') with bounds (14)
# phase : rank-1 array('d') with bounds (14)
# ox : rank-1 array('d') with bounds (600)
# ax : rank-1 array('d') with bounds (600)
# oy : rank-1 array('d') with bounds (600)
# ay : rank-1 array('d') with bounds (600)
# os : rank-1 array('d') with bounds (600)
# as : rank-1 array('d') with bounds (600)
#
# ========================================
#
#
# ========================================
# spectrum
# ----------------------------------------
# spectrum(x,xp,maxn,tune,zpesi,narm,meth)
#
# Wrapper for ``spectrum``.
#
# Parameters
# ----------
# x : input rank-1 array('d') with bounds (100000)
# xp : input rank-1 array('d') with bounds (100000)
# maxn : input int
# tune : input rank-1 array('d') with bounds (300)
# zpesi : input rank-1 array('D') with bounds (300)
# narm : input int
# meth : input int
#
# ========================================
#
#
# ========================================
# tunenewt
# ----------------------------------------
# tunenewt = tunenewt(x,xp,maxn,zw)
#
# Wrapper for ``tunenewt``.
#
# Parameters
# ----------
# x : input rank-1 array('d') with bounds (100000)
# xp : input rank-1 array('d') with bounds (100000)
# maxn : input int
# zw : input complex
#
# Returns
# -------
# tunenewt : float
#
# ========================================
#
#
# ========================================
# tunelasr
# ----------------------------------------
# tunelasr = tunelasr(x,xp,maxn,zw)
#
# Wrapper for ``tunelasr``.
#
# Parameters
# ----------
# x : input rank-1 array('d') with bounds (100000)
# xp : input rank-1 array('d') with bounds (100000)
# maxn : input int
# zw : input complex
#
# Returns
# -------
# tunelasr : float
#
# ========================================
#
#
# ========================================
# zfunr
# ----------------------------------------
# zfunr(tune,zw,z,maxn,tunea1,deltat)
#
# Wrapper for ``zfunr``.
#
# Parameters
# ----------
# tune : input float
# zw : input complex
# z : input rank-1 array('D') with bounds (100000)
# maxn : input int
# tunea1 : input float
# deltat : input float
#
# ========================================
#
#
# ========================================
# calcr
# ----------------------------------------
# calcr(zv,zpp,zp,maxd)
#
# Wrapper for ``calcr``.
#
# Parameters
# ----------
# zv : input complex
# zpp : input complex
# zp : input rank-1 array('D') with bounds (*)
# maxd : input int
#
# ========================================
#
#
# ========================================
# susres
# ----------------------------------------
# susres(nfile,nsus,max_bn,idams)
#
# Wrapper for ``susres``.
#
# Parameters
# ----------
# nfile : input int
# nsus : input int
# max_bn : input int
# idams : input int
#
# ========================================
#
#
# ========================================
# ordres
# ----------------------------------------
# ordres(eps,narm,nr,idam,iunit,nturn,tunex,tuney,tunez,istune,etune,amplitude,phase,ox,ax,oy,ay,os,as)
#
# Wrapper for ``ordres``.
#
# Parameters
# ----------
# eps : input float
# narm : input int
# nr : input int
# idam : input int
# iunit : input int
# nturn : input int
# tunex : input float
# tuney : input float
# tunez : input float
# istune : input int
# etune : input rank-1 array('d') with bounds (3)
# amplitude : input rank-1 array('d') with bounds (14)
# phase : input rank-1 array('d') with bounds (14)
# ox : input rank-1 array('d') with bounds (600)
# ax : input rank-1 array('d') with bounds (600)
# oy : input rank-1 array('d') with bounds (600)
# ay : input rank-1 array('d') with bounds (600)
# os : input rank-1 array('d') with bounds (600)
# as : input rank-1 array('d') with bounds (600)
#
# ========================================
#
#
# ========================================
# datspe
# ----------------------------------------
# datspe(iunit,idam,ir,nt1,nt2,nturn,imeth,narm,iana,x,xp,y,yp,s,sp,[n_points])
#
# Wrapper for ``datspe``.
#
# Parameters
# ----------
# iunit : input int
# idam : input int
# ir : input int
# nt1 : input int
# nt2 : input int
# nturn : input int
# imeth : input int
# narm : input int
# iana : input int
# x : input rank-1 array('d') with bounds (n_points)
# xp : input rank-1 array('d') with bounds (n_points)
# y : input rank-1 array('d') with bounds (n_points)
# yp : input rank-1 array('d') with bounds (n_points)
# s : input rank-1 array('d') with bounds (n_points)
# sp : input rank-1 array('d') with bounds (n_points)
#
# Other Parameters
# ----------------
# n_points : input int, optional
#     Default: shape(x, 0)
#
# ========================================
#
#
# ========================================
# fftr
# ----------------------------------------
# fftr(x,xp,maxn,zsing,meth)
#
# Wrapper for ``fftr``.
#
# Parameters
# ----------
# x : input rank-1 array('d') with bounds (100000)
# xp : input rank-1 array('d') with bounds (100000)
# maxn : input int
# zsing : input rank-1 array('F') with bounds (100000)
# meth : input int
#
# ========================================
#
#
# ========================================
# readres
# ----------------------------------------
# readres(imin,imax,lr,mr,kr,narm,idam,idamx,iout)
#
# Wrapper for ``readres``.
#
# Parameters
# ----------
# imin : input int
# imax : input int
# lr : input int
# mr : input int
# kr : input int
# narm : input int
# idam : input int
# idamx : input int
# iout : input int
#
# ========================================
#
#
# ========================================
# readdt3
# ----------------------------------------
# readdt3(imin,imax,narm,idam,iout)
#
# Wrapper for ``readdt3``.
#
# Parameters
# ----------
# imin : input int
# imax : input int
# narm : input int
# idam : input int
# iout : input int
#
# ========================================
#
#
# ========================================
# readdt4
# ----------------------------------------
# readdt4(imin,imax,narm,idam,iout)
#
# Wrapper for ``readdt4``.
#
# Parameters
# ----------
# imin : input int
# imax : input int
# narm : input int
# idam : input int
# iout : input int
#
# ========================================
#
#
# ========================================
# readsme
# ----------------------------------------
# readsme(imin,imax,narm,idam,idamx,iusm)
#
# Wrapper for ``readsme``.
#
# Parameters
# ----------
# imin : input int
# imax : input int
# narm : input int
# idam : input int
# idamx : input int
# iusm : input int
#
# ========================================
#
#
# ========================================
# readinv
# ----------------------------------------
# readinv(imin,imax,narm,idam,iinv)
#
# Wrapper for ``readinv``.
#
# Parameters
# ----------
# imin : input int
# imax : input int
# narm : input int
# idam : input int
# iinv : input int
#
# ========================================
#
#
# ========================================
# readric
# ----------------------------------------
# readric(nfile,idam,ntwin,iconv)
#
# Wrapper for ``readric``.
#
# Parameters
# ----------
# nfile : input int
# idam : input int
# ntwin : input int
# iconv : input int
#
# ========================================
#
#
# ========================================
# writeric
# ----------------------------------------
# writeric(nfile,ntwin,numl,iconv)
#
# Wrapper for ``writeric``.
#
# Parameters
# ----------
# nfile : input int
# ntwin : input int
# numl : input int
# iconv : input int
#
# ========================================
#
#
# ========================================
# kerset
# ----------------------------------------
# kerset(ercode,lgfile,limitm,limitr)
#
# Wrapper for ``kerset``.
#
# Parameters
# ----------
# ercode : input string(len=6)
# lgfile : input int
# limitm : input int
# limitr : input int
#
# ========================================
#
#
# ========================================
# kermtr
# ----------------------------------------
# kermtr(ercode,log,mflag,rflag)
#
# Wrapper for ``kermtr``.
#
# Parameters
# ----------
# ercode : input string(len=6)
# log : input int
# mflag : input int
# rflag : input int
#
# ========================================
#
#
# ========================================
# dinv
# ----------------------------------------
# dinv(a,ir,ifail,[n,idim])
#
# Wrapper for ``dinv``.
#
# Parameters
# ----------
# a : input rank-2 array('d') with bounds (idim,n)
# ir : input rank-1 array('i') with bounds (n)
# ifail : input int
#
# Other Parameters
# ----------------
# n : input int, optional
#     Default: shape(a, 1)
# idim : input int, optional
#     Default: shape(a, 0)
#
# ========================================
#
#
# ========================================
# f010pr
# ----------------------------------------
# f010pr(name,n,idim,k,kprnt)
#
# Wrapper for ``f010pr``.
#
# Parameters
# ----------
# name : input string(len=6)
# n : input int
# idim : input int
# k : input int
# kprnt : input int
#
# ========================================
#
#
# ========================================
# dfact
# ----------------------------------------
# dfact(n,a,ir,ifail,det,jfail,[idim])
#
# Wrapper for ``dfact``.
#
# Parameters
# ----------
# n : input int
# a : input rank-2 array('d') with bounds (idim,*)
# ir : input rank-1 array('i') with bounds (*)
# ifail : input int
# det : input float
# jfail : input int
#
# Other Parameters
# ----------------
# idim : input int, optional
#     Default: shape(a, 0)
#
# ========================================
#
#
# ========================================
# dfinv
# ----------------------------------------
# dfinv(n,a,ir,[idim])
#
# Wrapper for ``dfinv``.
#
# Parameters
# ----------
# n : input int
# a : input rank-2 array('d') with bounds (idim,*)
# ir : input rank-1 array('i') with bounds (*)
#
# Other Parameters
# ----------------
# idim : input int, optional
#     Default: shape(a, 0)
#
# ========================================
#
#
# ========================================
# tmprnt
# ----------------------------------------
# tmprnt(name,n,idim,k)
#
# Wrapper for ``tmprnt``.
#
# Parameters
# ----------
# name : input string(len=6)
# n : input int
# idim : input int
# k : input int
#
# ========================================
#
#
# ========================================
# abend
# ----------------------------------------
# abend()
#
# Wrapper for ``abend``.
#
#
# ========================================
#
#
# ========================================
# cfft
# ----------------------------------------
# cfft(a,msign)
#
# Wrapper for ``cfft``.
#
# Parameters
# ----------
# a : input rank-1 array('F') with bounds (100000)
# msign : input int
#
# ========================================
#
#
# ========================================
# tune
# ----------------------------------------
# txa : 'd'-array(300)
# tya : 'd'-array(300)
# tsa : 'd'-array(300)
#
# ========================================
#
#
# ========================================
# data
# ----------------------------------------
# x : 'd'-array(100000)
# y : 'd'-array(100000)
# xp : 'd'-array(100000)
# yp : 'd'-array(100000)
# s : 'd'-array(100000)
# sp : 'd'-array(100000)
#
# ========================================
#
#
# ========================================
# fcoe
# ----------------------------------------
# zxpes : 'D'-array(300)
# zypes : 'D'-array(300)
# zspes : 'D'-array(300)
#
# ========================================
#
#
# ========================================
# dt
# ----------------------------------------
# dtpx : 'd'-array(1000)
# dtfx : 'd'-array(1000)
# dttx : 'd'-array(1000)
#
# ========================================
